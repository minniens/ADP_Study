# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine

wine_load = load_wine()
wine = pd.DataFrame(wine_load.data, columns=wine_load.feature_names)
wine['Class'] = wine_load.target
wine['Class'] = wine['Class'].map({0:'class_0', 1:'class_1', 2:'class_2'})
wine_type = wine['Class'].value_counts()
wine_type
# Out:
# class_1    71
# class_0    59
# class_2    48
# Name: Class, dtype: int64

# %%
wine
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      od280/od315_of_diluted_wines  proline    Class
# 0                            3.92   1065.0  class_0
# 1                            3.40   1050.0  class_0
# 2                            3.17   1185.0  class_0
# 3                            3.45   1480.0  class_0
# 4                            2.93    735.0  class_0
# ..                            ...      ...      ...
# 173                          1.74    740.0  class_2
# 174                          1.56    750.0  class_2
# 175                          1.56    835.0  class_2
# 176                          1.62    840.0  class_2
# 177                          1.60    560.0  class_2
#
# [178 rows x 14 columns]

# %%
plt.bar?

# %%
plt.bar(wine_type.index, wine_type.values, color='yellow')
plt.show()

# %%
plt.barh(wine_type.index, wine_type.values)
plt.show()

# %%
plt.title('Wine alcohol histogram')
plt.hist('alcohol', bins = 8, range = (11, 15), color='purple', data = wine)
plt.show()

# %%
plt.title('Wine alcohol histogram')
plt.hist(wine['alcohol'], bins = 10, range = (wine['alcohol'].min(), wine['alcohol'].max()), color='red', density=True)
plt.show()

# %%
import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris()
iris = pd.DataFrame(iris.data, columns=iris.feature_names)
iris['Class'] = load_iris().target
iris['Class'] = iris['Class'].map({0:'Setosa', 1:'Versicolour', 2:'Virginica'})

iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#          Class
# 0       Setosa
# 1       Setosa
# 2       Setosa
# 3       Setosa
# 4       Setosa
# ..         ...
# 145  Virginica
# 146  Virginica
# 147  Virginica
# 148  Virginica
# 149  Virginica
#
# [150 rows x 5 columns]

# %%
iris.drop(columns=['Class'])
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
plt.boxplot(iris[['sepal length (cm)','sepal width (cm)']])
plt.show()

# %%
import matplotlib.pyplot as plt
iris.drop(columns='Class').boxplot()
plt.show()

# %%
iris.boxplot(by='Class')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(x="Class", y="sepal width (cm)", data=iris)
plt.show()

# %%
sns.boxplot?

# %%
plt.title('iris scatter') 
plt.xlabel('sepal length (cm)')
plt.ylabel('sepal width (cm)') 

plt.scatter(x = iris['sepal length (cm)'], y = iris['sepal width (cm)'], alpha = 0.1)
plt.show()

# %%
sns.scatterplot(x = iris['sepal length (cm)'], y = iris['sepal width (cm)'], data=iris, hue='Class')

# %%
plt.hlines(-6, -10, 10, color='grey')
plt.hlines(-2, -10, 10, color='green')
plt.hlines(2, -10, 10, color='orange')
plt.hlines(6, -10, 10, color='red')

plt.vlines(-6, -10, 10, linestyles='solid')
plt.vlines(-2, -10, 10, linestyles='dashed')
plt.vlines(2, -10, 10, linestyles='dashdot')
plt.vlines(6, -10, 10, linestyles='dotted')
plt.show()

# %%
plt.plot(iris['sepal length (cm)'],2*iris['sepal length (cm)'] + 1)

# %%
plt.plot(iris['sepal length (cm)']) ##파라미터 하나 넣으면 y축으로 간주(X축은 index 인듯), 두개넣으면 x,y로 간주

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal length (cm)    150 non-null float64
# sepal width (cm)     150 non-null float64
# petal length (cm)    150 non-null float64
# petal width (cm)     150 non-null float64
# Class                150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
import numpy as np

# %%
b1, b0 = np.polyfit(iris['sepal length (cm)'], iris['petal length (cm)'], deg=1)

plt.scatter(x = iris['sepal length (cm)'], y = iris['petal length (cm)'], alpha = 0.5)
plt.plot(iris['sepal length (cm)'], b1*iris['sepal length (cm)'] + b0, color='red')
plt.show()

# %%
# 2차식을 그리는 경우에 주의사항으로 데이터를 X값에 대하여 정렬할 필요가 있다. 
# -> 왜? (x0, y0)좌표에서 (x1, y1)좌표로 연결되는 선이 무수히 많아 곡선처럼 보일 뿐. 순서대로 정렬되어 있지 않으면 선이 한방향으로 이어지지 않고 왔다 갔다함.

iris2 = iris.sort_values(by='sepal length (cm)')
#iris2=iris
X, Y = iris2['sepal length (cm)'], iris2['petal length (cm)']
b2, b1, b0 = np.polyfit(X, Y, 2)

plt.scatter(x = X, y = Y, alpha = 0.5)
plt.plot(X, b0 + b1*X + b2*X**2, color='red')
plt.show()

# %%
iris2 = iris.sort_values(by='sepal length (cm)')
#plt.plot(iris2['sepal length (cm)'], iris2['petal length (cm)'])
plt.plot('sepal length (cm)', 'petal length (cm)', data=iris2)
plt.show()

# %%
plt.plot('sepal length (cm)', 'petal length (cm)', data=iris2.loc[iris2['Class'] == 'Setosa'])
plt.plot('sepal length (cm)', 'petal length (cm)', data=iris2.loc[iris2['Class'] == 'Versicolour'])
plt.plot('sepal length (cm)', 'petal length (cm)', data=iris2.loc[iris2['Class'] == 'Virginica'])
plt.legend(iris2.Class.unique())
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
from sklearn.datasets import load_iris

iris = load_iris()
iris = pd.DataFrame(iris.data, columns=iris.feature_names)
iris['Class'] = load_iris().target
iris['Class'] = iris['Class'].map({0:'Setosa', 1:'Versicolour', 2:'Virginica'})

scatter_matrix(iris, alpha = 0.5, figsize = (10, 10), diagonal = 'hist') ##kde : Histogram을 smoothing 시켜서 그린 곡선
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(iris, hue='Class')
plt.show()

# %%
iris.corr()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)           1.000000

# %%
iris_corr = iris.drop(columns='Class').corr(method='pearson')
sns.heatmap(iris_corr, xticklabels = iris_corr.columns, yticklabels = iris_corr.columns, cmap = 'RdBu_r', annot = True)
plt.show()

# %%
# !pip install pandas-profiling[notebook,html]
# Out:
# Collecting pandas-profiling[html,notebook]
#   Downloading https://files.pythonhosted.org/packages/ac/cb/f038b9b57c6edaaf6f4e400b0bb1d954bc08dc6bc61a4b0861acecd3789c/pandas_profiling-3.6.6-py2.py3-none-any.whl (324kB)
# Collecting ydata-profiling (from pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/33/85/45027914eb485482976883dcaab434eab99f1ed5cb222781e7ba46bdf3b7/ydata_profiling-4.8.3-py2.py3-none-any.whl (359kB)
# Requirement already satisfied: ipywidgets>=7.5.1; extra == "notebook" in c:\users\rkddn\anaconda3\lib\site-packages (from pandas-profiling[html,notebook]) (7.5.1)
# Collecting jupyter-client>=5.3.4; extra == "notebook" (from pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/fd/a7/ef3b7c8b9d6730a21febdd0809084e4cea6d2a7e43892436adecdd0acbd4/jupyter_client-7.4.9-py3-none-any.whl (133kB)
# Collecting jupyter-core>=4.6.3; extra == "notebook" (from pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/02/8f/0e0ad6804c0a021a27410ec997626a7a955c20916454d0205f16eb83de4b/jupyter_core-4.12.0-py3-none-any.whl (89kB)
# Collecting multimethod<2,>=1.4 (from ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/21/91/01ec16d3d0cadb499b83e6f6435c63e43f3c122c146d82a4eb9575169817/multimethod-1.9.1-py3-none-any.whl
# Collecting imagehash==4.3.1 (from ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/2d/b4/19a746a986c6e38595fa5947c028b1b8e287773dcad766e648897ad2a4cf/ImageHash-4.3.1-py2.py3-none-any.whl (296kB)
# Collecting numba<1,>=0.56.0 (from ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/ad/5a/b79eda6012461c4dea6c5c4122c7438843d617f960d2d635f044a97ab912/numba-0.56.4-cp37-cp37m-win_amd64.whl (2.5MB)
# Collecting pydantic>=2 (from ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/dd/b7/9aea7ee6c01fe3f3c03b8ca3c7797c866df5fecece9d6cb27caa138db2e2/pydantic-2.5.3-py3-none-any.whl (381kB)
# Collecting dacite>=1.8 (from ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/21/0f/cf0943f4f55f0fbc7c6bd60caf1343061dff818b02af5a0d444e473bb78d/dacite-1.8.1-py3-none-any.whl
# Collecting jinja2<3.2,>=2.11.1 (from ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/31/80/3a54838c3fb461f6fec263ebf3a3a41771bd05190238de3486aae8540c36/jinja2-3.1.4-py3-none-any.whl (133kB)
# Collecting htmlmin==0.1.12 (from ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/b3/e7/fcd59e12169de19f0131ff2812077f964c6b960e7c09804d30a7bf2ab461/htmlmin-0.1.12.tar.gz
# Collecting typeguard<5,>=3 (from ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/bb/bd/dc7da80c95c920ee2b575e64901b5962ca4a1271b5f3cf6c27242aa0aafc/typeguard-4.1.2-py3-none-any.whl
# Collecting statsmodels<1,>=0.13.2 (from ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/62/74/b54c3defc82f61301aafa56b4abd67f830ab4575dec13a1b895f09d35dfc/statsmodels-0.13.5-cp37-cp37m-win_amd64.whl (9.1MB)
# Collecting matplotlib<3.9,>=3.2 (from ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/df/3f/6093a23565d0f50ce433f56223fcc34af6c912cd4331dc582ba29d9b5a17/matplotlib-3.5.3-cp37-cp37m-win_amd64.whl (7.2MB)
# Collecting wordcloud>=1.9.1 (from ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/4b/12/a489555dd7cdc8ee87e8dab071b6697271dfc57fc00fbe9b9e04c80354ea/wordcloud-1.9.3-cp37-cp37m-win_amd64.whl (300kB)
# Collecting visions[type_image_path]<0.7.7,>=0.7.5 (from ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/62/fa/6a8539c83d2ccbd08d5f0c843b1784af9ff514e77f4c9d5d6800fdd340f6/visions-0.7.5-py3-none-any.whl (102kB)
# Collecting requests<3,>=2.24.0 (from ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/70/8e/0e2d847013cb52cd35b38c009bb167a1a26b2ce6cd6965bf26b47bc0bf44/requests-2.31.0-py3-none-any.whl (62kB)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\rkddn\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling[html,notebook]) (5.1.2)
# Requirement already satisfied: scipy<1.14,>=1.4.1 in c:\users\rkddn\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling[html,notebook]) (1.5.2)
# Collecting pandas!=1.4.0,<3,>1.1 (from ydata-profiling->pandas-profiling[html,notebook])
#   Using cached https://files.pythonhosted.org/packages/b2/56/f886ed6f1777ffa9d54c6e80231b69db8a1f52dcc33f5967b06a105dcfe0/pandas-1.3.5-cp37-cp37m-win_amd64.whl
# Requirement already satisfied: numpy<2,>=1.16.0 in c:\users\rkddn\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling[html,notebook]) (1.18.5)
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/b7/b3/e327612b67b2ab93749e648a92e5463cba763e7d4e8c74f69551133df076/phik-0.12.3-cp37-cp37m-win_amd64.whl (664kB)
# Collecting seaborn<0.14,>=0.10.1 (from ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/8f/2e/17bbb83fbf102687bb2aa3d808add39da820a7698159302a1a69bb82e01c/seaborn-0.12.2-py3-none-any.whl (293kB)
# Collecting tqdm<5,>=4.48.2 (from ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/18/eb/fdb7eb9e48b7b02554e1664afd3bd3f117f6b6d6c5881438a0b055554f9b/tqdm-4.66.4-py3-none-any.whl (78kB)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in c:\users\rkddn\anaconda3\lib\site-packages (from ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (7.8.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\rkddn\anaconda3\lib\site-packages (from ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (4.3.3)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\rkddn\anaconda3\lib\site-packages (from ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (4.4.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\rkddn\anaconda3\lib\site-packages (from ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\rkddn\anaconda3\lib\site-packages (from ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (5.1.2)
# Collecting pyzmq>=23.0 (from jupyter-client>=5.3.4; extra == "notebook"->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/2b/67/f6569c49cf522594ab155487755a0c21b1682f2038466d0a3de6b7efaec1/pyzmq-26.0.3-cp37-cp37m-win_amd64.whl (799kB)
# Collecting nest-asyncio>=1.5.4 (from jupyter-client>=5.3.4; extra == "notebook"->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/a0/c4/c2971a3ba4c6103a3d10c4b0f24f461ddc027f0f09763220cf35ca1401b3/nest_asyncio-1.6.0-py3-none-any.whl
# Collecting python-dateutil>=2.8.2 (from jupyter-client>=5.3.4; extra == "notebook"->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/ec/57/56b9bcc3c9c6a792fcbaf139543cee77261f3651ca9da0c93f5c1221264b/python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229kB)
# Collecting tornado>=6.2 (from jupyter-client>=5.3.4; extra == "notebook"->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/f3/9e/225a41452f2d9418d89be5e32cf824c84fe1e639d350d6e8d49db5b7f73a/tornado-6.2.tar.gz (504kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: entrypoints in c:\users\rkddn\anaconda3\lib\site-packages (from jupyter-client>=5.3.4; extra == "notebook"->pandas-profiling[html,notebook]) (0.3)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" and platform_python_implementation != "PyPy" in c:\users\rkddn\anaconda3\lib\site-packages (from jupyter-core>=4.6.3; extra == "notebook"->pandas-profiling[html,notebook]) (223)
# Requirement already satisfied: pillow in c:\users\rkddn\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling[html,notebook]) (6.2.0)
# Requirement already satisfied: PyWavelets in c:\users\rkddn\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling[html,notebook]) (1.0.3)
# Collecting llvmlite<0.40,>=0.39.0dev0 (from numba<1,>=0.56.0->ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/be/05/af5fd325c52b73255a51691300f00b06177dfe1088b90ea20dd49c6e0c23/llvmlite-0.39.1-cp37-cp37m-win_amd64.whl (23.2MB)
# Requirement already satisfied: setuptools in c:\users\rkddn\anaconda3\lib\site-packages (from numba<1,>=0.56.0->ydata-profiling->pandas-profiling[html,notebook]) (41.4.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.9" in c:\users\rkddn\anaconda3\lib\site-packages (from numba<1,>=0.56.0->ydata-profiling->pandas-profiling[html,notebook]) (0.23)
# Collecting pydantic-core==2.14.6 (from pydantic>=2->ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/00/9f/bca85affee28fff3d8fd848643f6c7bbcbd0567c07f2fb2e5c8e5690f6e8/pydantic_core-2.14.6-cp37-none-win_amd64.whl (1.9MB)
# Collecting typing-extensions>=4.6.1 (from pydantic>=2->ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/ec/6b/63cc3df74987c36fe26157ee12e09e8f9db4de771e0f3404263117e75b95/typing_extensions-4.7.1-py3-none-any.whl
# Collecting annotated-types>=0.4.0 (from pydantic>=2->ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/d8/f0/a2ee543a96cc624c35a9086f39b1ed2aa403c6d355dfe47a11ee5c64a164/annotated_types-0.5.0-py3-none-any.whl
# Collecting MarkupSafe>=2.0 (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/6c/4c/3577a52eea1880538c435176bc85e5b3379b7ab442327ccd82118550758f/MarkupSafe-2.1.5-cp37-cp37m-win_amd64.whl
# Collecting packaging>=21.3 (from statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/49/df/1fceb2f8900f8639e278b056416d49134fb8d84c5942ffaa01ad34782422/packaging-24.0-py3-none-any.whl (53kB)
# Collecting patsy>=0.5.2 (from statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/43/f3/1d311a09c34f14f5973bb0bb0dc3a6e007e1eda90b5492d082689936ca51/patsy-0.5.6-py2.py3-none-any.whl (233kB)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\rkddn\anaconda3\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->pandas-profiling[html,notebook]) (2.4.2)
# Collecting fonttools>=4.22.0 (from matplotlib<3.9,>=3.2->ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/e3/d9/e9bae85e84737e76ebbcbea13607236da0c0699baed0ae4f1151b728a608/fonttools-4.38.0-py3-none-any.whl (965kB)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rkddn\anaconda3\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->pandas-profiling[html,notebook]) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rkddn\anaconda3\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling->pandas-profiling[html,notebook]) (0.10.0)
# Collecting tangled-up-in-unicode>=0.0.4 (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/dd/60/3651960b74aead282ec1ad819e70bdccf3ee73322d13d4339a6e3f5b7ed3/tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7MB)
# Collecting attrs>=19.3.0 (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/e0/44/827b2a91a5816512fcaf3cc4ebc465ccd5d598c45cefa6703fcf4a79018f/attrs-23.2.0-py3-none-any.whl (60kB)
# Collecting networkx>=2.4 (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/e9/93/aa6613aa70d6eb4868e667068b5a11feca9645498fd31b954b6c4bb82fa5/networkx-2.6.3-py3-none-any.whl (1.9MB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rkddn\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling[html,notebook]) (2.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rkddn\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling[html,notebook]) (1.24.2)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/96/fc/0cae31c0f150cd1205a2a208079de865f69a8fd052a98856c40c99e36b3c/charset_normalizer-3.3.2-cp37-cp37m-win_amd64.whl (98kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rkddn\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling[html,notebook]) (2019.9.11)
# Requirement already satisfied: pytz>=2017.3 in c:\users\rkddn\anaconda3\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling->pandas-profiling[html,notebook]) (2019.3)
# Collecting joblib>=0.14.1 (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling[html,notebook])
#   Downloading https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl (302kB)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\rkddn\anaconda3\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling->pandas-profiling[html,notebook]) (0.4.1)
# Requirement already satisfied: pygments in c:\users\rkddn\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (2.4.2)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in c:\users\rkddn\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (2.0.10)
# Requirement already satisfied: pickleshare in c:\users\rkddn\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (0.7.5)
# Requirement already satisfied: decorator in c:\users\rkddn\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (4.4.0)
# Requirement already satisfied: backcall in c:\users\rkddn\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (0.1.0)
# Requirement already satisfied: jedi>=0.10 in c:\users\rkddn\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (0.15.1)
# Requirement already satisfied: ipython-genutils in c:\users\rkddn\anaconda3\lib\site-packages (from traitlets>=4.3.1->ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (0.2.0)
# Requirement already satisfied: six in c:\users\rkddn\anaconda3\lib\site-packages (from traitlets>=4.3.1->ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (1.12.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\rkddn\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (3.0.2)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\rkddn\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (6.0.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\rkddn\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.9"->numba<1,>=0.56.0->ydata-profiling->pandas-profiling[html,notebook]) (0.6.0)
# Requirement already satisfied: wcwidth in c:\users\rkddn\anaconda3\lib\site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (0.1.7)
# Requirement already satisfied: parso>=0.5.0 in c:\users\rkddn\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (0.5.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\rkddn\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (0.15.4)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\rkddn\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (0.8.2)
# Requirement already satisfied: Send2Trash in c:\users\rkddn\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (1.5.0)
# Requirement already satisfied: prometheus-client in c:\users\rkddn\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (0.7.1)
# Requirement already satisfied: nbconvert in c:\users\rkddn\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (5.6.0)
# Requirement already satisfied: more-itertools in c:\users\rkddn\anaconda3\lib\site-packages (from zipp>=0.5->importlib-metadata; python_version < "3.9"->numba<1,>=0.56.0->ydata-profiling->pandas-profiling[html,notebook]) (7.2.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\rkddn\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (1.4.2)
# Requirement already satisfied: testpath in c:\users\rkddn\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (0.4.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\rkddn\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (0.8.4)
# Requirement already satisfied: bleach in c:\users\rkddn\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (3.1.0)
# Requirement already satisfied: defusedxml in c:\users\rkddn\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (0.6.0)
# Requirement already satisfied: webencodings in c:\users\rkddn\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1; extra == "notebook"->pandas-profiling[html,notebook]) (0.5.1)
# Building wheels for collected packages: tornado
#   Building wheel for tornado (PEP 517): started
#   Building wheel for tornado (PEP 517): finished with status 'done'
#   Created wheel for tornado: filename=tornado-6.2-cp37-abi3-win_amd64.whl size=417696 sha256=d57be8aa15e775bca451c7d493d497c33f8fff5481fe4cec3b08ad4c0d96c0a9
#   Stored in directory: C:\Users\rkddn\AppData\Local\pip\Cache\wheels\4c\e2\a2\2a4d8b655b5018edd788430e998bfb2e15a2b7876dbee210e6
# Successfully built tornado
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-cp37-none-any.whl size=27090 sha256=f9f80a68febccbaa1a1d08bba2019432c055b57a8275a1f1163481508e466dc1
#   Stored in directory: C:\Users\rkddn\AppData\Local\pip\Cache\wheels\43\07\ac\7c5a9d708d65247ac1f94066cf1db075540b85716c30255459
# Successfully built htmlmin
# Installing collected packages: multimethod, imagehash, llvmlite, numba, typing-extensions, pydantic-core, annotated-types, pydantic, dacite, MarkupSafe, jinja2, htmlmin, typeguard, python-dateutil, pandas, packaging, patsy, statsmodels, fonttools, matplotlib, wordcloud, tangled-up-in-unicode, attrs, networkx, visions, charset-normalizer, requests, joblib, phik, seaborn, tqdm, ydata-profiling, jupyter-core, pyzmq, nest-asyncio, tornado, jupyter-client, pandas-profiling
#   Found existing installation: llvmlite 0.29.0
#   WARNING: pandas-profiling 3.6.6 does not provide the extra 'html'
# ERROR: spyder 3.3.6 requires pyqt5<5.13; python_version >= "3", which is not installed.
# ERROR: spyder 3.3.6 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
# ERROR: typeguard 4.1.2 has requirement importlib-metadata>=3.6; python_version < "3.10", but you'll have importlib-metadata 0.23 which is incompatible.
# ERROR: Cannot uninstall 'llvmlite'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
